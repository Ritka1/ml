# %% [markdown]
# # Data Science in der Produktion
# ## Uebung 2: Modellbildung

# %%
from IPython.display import display, Math, Latex
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %% [markdown]
# Fügen Sie Ihren Namen in die untenstehenden Zelle ein und führen Sie diese aus.

# %%
name = ""
print("Mein Name lautet: ", name)

# %% [markdown]
# **Klassifikation von Iris-Arten**
#
# In diesem Notebook werden Sie eine einfache maschinelle Lernanwendung bearbeiten und ein Modell erstellen. Ziel der Applikation ist es die Art verschiedener Irisblüten zu unterscheiden. Dazu wird ein open-source Datenset verwendet, welches die Länge und Breite der Blütenblätter sowie die Länge und Breite der Kelchblätter enthält.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Als Datenbasis kommt der Iris-Datensatz zum Einsatz. Der Datensatz ist im scikit-learn Datensatzmodul enthalten und kann durch die Funktion load_iris geladen werden:

# %%
from sklearn.datasets import load_iris
iris_dataset = load_iris()

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Keys of iris_dataset: \n{}".format(iris_dataset.keys()))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Target names: {}".format(iris_dataset['target_names']))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Feature names: \n{}".format(iris_dataset['feature_names']))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Type of data: {}".format(type(iris_dataset['data'])))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Shape of data: {}".format(iris_dataset['data'].shape))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("First five columns of data:\n{}".format(iris_dataset['data'][:5]))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Type of target: {}".format(type(iris_dataset['target'])))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Shape of target: {}".format(iris_dataset['target'].shape))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Target:\n{}".format(iris_dataset['target']))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
 iris_dataset['data'], iris_dataset['target'], random_state=0)

# %% [markdown]
# Ausgeben der shape des Trainings- und Testdatensatzes.

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))

# %%
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))

# %% [markdown]
# Visualisierung der Daten mittels Paarplot.

# %%
import pandas as pd
# create dataframe from data in X_train
# label the columns using the strings in iris_dataset.feature_names
from sklearn import datasets

iris_dataset = datasets.load_iris()
X = iris_dataset.data
Y = iris_dataset.target

iris_dataframe = pd.DataFrame(X, columns=iris_dataset.feature_names)

# Create a scatter matrix from the dataframe, color by y_train
grr = pd.plotting.scatter_matrix(iris_dataframe, c=Y, figsize=(15, 15), marker='o',
                                 hist_kwds={'bins': 20}, s=60, alpha=.8)

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
knn.fit(X_train, y_train)

# %% [markdown]
# Generierung unbekannter Daten.

# %%
X_new = np.array([[5, 2.9, 1, 0.2]])
print("X_new.shape: {}".format(X_new.shape))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
prediction = knn.predict(X_new)
print("Prediction: {}".format(prediction))
print("Predicted target name: {}".format(
 iris_dataset['target_names'][prediction]))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
y_pred = knn.predict(X_test)
print("Test set predictions:\n {}".format(y_pred))

# %% [markdown]
#  < -Kommentar einfuegen >
#  ...

# %%
print("Test set score: {:.2f}".format(knn.score(X_test, y_test)))

# %% [markdown]
# Für dieses Modell liegt die Genauigkeit auf dem Testsets bei 0,97%.
